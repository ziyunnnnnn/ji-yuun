# %% [markdown]
# # 출산율 자료 로딩

# %%
# 모듈 로딩
import pandas as pd 

# 파일관련 변수 선언 
DIR_PATH='../Data2/'
FILE_NAME=DIR_PATH+'출산율.csv'
FILE_NAME
# Out:
# '../Data2/출산율.csv'

# %%
# DF 형태 데이터로 로딩
df=pd.read_csv(FILE_NAME)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Columns: 161 entries, 시도별 to 2020.3
# dtypes: object(161)
# memory usage: 24.0+ KB

# %% [markdown]
# # 결혼율 파일 로딩

# %%
# 파일관련 변수 선언
DIR_PATH='../Data2/'
FILE_NAME=DIR_PATH+'결혼율.csv'
FILE_NAME
# Out:
# '../Data2/결혼율.csv'

# %%
# DF 형태 데이터로 로딩
marriage=pd.read_csv(FILE_NAME)
marriage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Columns: 301 entries, 시군구별 to 2021.12
# dtypes: int64(156), object(145)
# memory usage: 44.8+ KB

# %%
# df출력
marriage
# Out:
#        시군구별  1997.01  1997.02  1997.03  1997.04  1997.05  1997.06  1997.07  \
# 0        전국    34930    28299    32684    33559    40012    33895    26475
# 1     서울특별시     8000     6238     7428     7965     9776     8591     6747
# 2     부산광역시     2770     2284     2419     2084     2805     2510     2015
# 3     대구광역시     1940     1633     1732     1516     1957     1647     1269
# 4     인천광역시     1704     1362     1536     1786     2235     1832     1446
# 5     광주광역시     1018      841      996      958     1118      911      701
# 6     대전광역시      927      750      904      971     1054      911      688
# 7     울산광역시      739      703      746      694      977      819      541
# 8   세종특별자치시        0        0        0        0        0        0        0
# 9       경기도     6327     4972     6070     6830     8117     6784     5180
# 10      강원도      878      667      915     1047     1221      996      798
# 11     충청북도     1052      896     1005     1049     1215      925      746
# 12     충청남도     1221      989     1194     1357     1391     1083      856
# 13     전라북도     1417     1115     1377     1271     1409     1082      888
# 14     전라남도     1496     1234     1379     1323     1399     1118     1024
# 15     경상북도     2005     1698     1961     1855     2119     1833     1337
# 16     경상남도     2487     2182     2114     1871     2402     2048     1513
# 17  제주특별자치도      419      428      464      426      379      415      270
# 18       국외      530      307      444      556      438      390      456
#
#     1997.08  1997.09  ...  2021.03  2021.04  2021.05  2021.06  2021.07  \
# 0     21718    19336  ...    16762    15861    16153    16235    15739
# 1      5368     4722  ...     3331     2998     3092     3034     3106
# 2      1592     1389  ...      985      877      908      979      757
# 3       997      831  ...      676      610      610      644      543
# 4      1210     1046  ...      917      917      900      987     1031
# 5       564      542  ...      470      401      422      414      375
# 6       576      496  ...      488      463      481      466      436
# 7       462      397  ...      375      370      353      348      285
# 8         0        0  ...      104      126      126      142      153
# 9      4316     3850  ...     4669     4454     4624     4645     4640
# 10      635      615  ...      473      456      518      476      436
# 11      572      580  ...      510      474      497      535      485
# 12      791      739  ...      692      671      680      666      633
# 13      774      699  ...      436      434      434      422      433
# 14      849      841  ...      575      499      503      473      455
# 15     1151      992  ...      715      723      676      644      619
# 16     1287     1094  ...      847      904      851      889      837
# 17      220      191  ...      216      217      240      230      213
# 18      354      312  ...      283      267      238      241      302
#
#     2021.08  2021.09  2021.1  2021.11  2021.12
# 0     14720    13733   15203    17088    19761
# 1      2851     2698    2858     3107     3754
# 2       825      778     854     1027     1194
# 3       522      479     544      619      764
# 4       818      757     848      868     1083
# 5       427      350     341      442      479
# 6       365      368     496      471      540
# 7       299      275     311      382      430
# 8       127      105     109      147      155
# 9      4291     4031    4450     4892     5560
# 10      362      422     503      569      558
# 11      432      397     493      513      621
# 12      629      554     632      762      843
# 13      430      407     426      488      539
# 14      483      382     404      522      596
# 15      549      579     590      798      950
# 16      848      738     862      943     1090
# 17      194      190     202      223      300
# 18      268      223     280      315      305
#
# [19 rows x 301 columns]

# %%
# 전국, 서울, 대구 행만 불러오기
marriage=marriage.iloc[[0,1,3]]

# %%
# 2011~2020의 6월 자료만 추출
year_list=[]
for i in range(2011, 2021):
    data=i
    data=str(data)
    data2=data+'.06'
    year_list.append(data2)
year_list
marriage.loc[:,year_list]
# Out:
#   2011.06  2012.06  2013.06  2014.06  2015.06  2016.06  2017.06  2018.06  \
# 0   27882    26009    26215    24789    26737    24285    22292    20610
# 1    6039     5600     5498     5299     5564     5003     4588     4143
# 3    1226     1072     1123     1005     1118     1077      963      890
#
#    2019.06  2020.06
# 0    17942    17184
# 1     3683     3665
# 3      737      606

# %%
# 각 연도 별 6월 자료만 추출
marriage=marriage[['2011.06', '2012.06', '2013.06', '2014.06', '2015.06', '2016.06', '2017.06', '2018.06', '2019.06', '2020.05']]

# %%
# 인덱스 설정
marriage.index=['전국', '서울', '대구']
# 컬럼명 설정
marriage=marriage.rename(columns={'2011.06':'2011', '2012.06':'2012','2013.06':'2013','2014.06':'2014','2015.06':'2015','2016.06':'2016','2017.06':'2017','2018.06':'2018','2019.06':'2019','2020.05':'2020'})
marriage
# Out:
#      2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# 전국  27882  26009  26215  24789  26737  24285  22292  20610  17942  18144
# 서울   6039   5600   5498   5299   5564   5003   4588   4143   3683   3859
# 대구   1226   1072   1123   1005   1118   1077    963    890    737    690

# %%
# 결혼 필요성에 대한 인식
DIR_PATH='../Data2/'
FILE_NAME=DIR_PATH+'결혼필요성및적정시기.xlsx'
FILE_NAME
# Out:
# '../Data2/결혼필요성및적정시기.xlsx'

# %%
# 
m_necessity=pd.read_excel(FILE_NAME)

# %%
m_necessity.info()
m_necessity.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   특성별(1)  7 non-null      object
#  1   특성별(2)  28 non-null     object
#  2   2017    19 non-null     object
#  3   2017.1  19 non-null     object
#  4   2017.2  19 non-null     object
#  5   2017.3  19 non-null     object
#  6   2018    19 non-null     object
#  7   2018.1  19 non-null     object
#  8   2018.2  19 non-null     object
#  9   2018.3  19 non-null     object
#  10  2019    19 non-null     object
#  11  2019.1  19 non-null     object
#  12  2019.2  19 non-null     object
#  13  2019.3  19 non-null     object
#  14  2020    19 non-null     object
#  15  2020.1  19 non-null     object
#  16  2020.2  19 non-null     object
#  17  2020.3  19 non-null     object
#  18  2021    11 non-null     object
#  19  2021.1  11 non-null     object
#  20  2021.2  11 non-null     object
#  21  2021.3  11 non-null     object
# dtypes: object(22)
# memory usage: 4.9+ KB
#    특성별(1)   특성별(2)        2017       2017.1                     2017.2  \
# 0  특성별(1)   특성별(2)  결혼해야 함 (%)  결혼 평균연령 (세)  결혼할 수도 있고 하지 않을 수도 있음 (%)
# 1      전체       소계        53.9         30.2                       40.7
# 2      성별       남자        59.7         30.5                       36.4
# 3     NaN       여자        47.6         29.8                       45.5
# 4     연령별  만15-18세        53.9           29                         42
#
#           2017.3        2018       2018.1                     2018.2  \
# 0  결혼할 필요 없음 (%)  결혼해야 함 (%)  결혼 평균연령 (세)  결혼할 수도 있고 하지 않을 수도 있음 (%)
# 1            5.3        42.9         30.9                       49.3
# 2            3.9        45.4         31.2                       48.1
# 3            6.9        40.2         30.5                       50.6
# 4            4.2          45         30.9                       44.7
#
#           2018.3  ...                     2019.2         2019.3        2020  \
# 0  결혼할 필요 없음 (%)  ...  결혼할 수도 있고 하지 않을 수도 있음 (%)  결혼할 필요 없음 (%)  결혼해야 함 (%)
# 1            7.8  ...                       47.9            6.2          42
# 2            6.5  ...                       44.4            4.3        47.1
# 3            9.2  ...                       51.9            8.4        36.3
# 4           10.3  ...                       45.5            7.8         NaN
#
#         2020.1                     2020.2         2020.3        2021  \
# 0  결혼 평균연령 (세)  결혼할 수도 있고 하지 않을 수도 있음 (%)  결혼할 필요 없음 (%)  결혼해야 함 (%)
# 1         30.7                       51.8            6.2        39.1
# 2         31.1                       48.2            4.7        42.1
# 3         30.1                       55.9            7.8        35.7
# 4          NaN                        NaN            NaN         NaN
#
#         2021.1                     2021.2         2021.3
# 0  결혼 평균연령 (세)  결혼할 수도 있고 하지 않을 수도 있음 (%)  결혼할 필요 없음 (%)
# 1         30.9                       54.3            6.6
# 2         31.3                         53            4.9
# 3         30.4                       55.8            8.5
# 4          NaN                        NaN            NaN
#
# [5 rows x 22 columns]

# %%
m_necessity=m_necessity.iloc[[0,1]]

# %%
m_necessity=m_necessity[['2017','2017.3','2018','2018.3','2019','2019.3','2020','2020.3']]
m_necessity
# Out:
#          2017         2017.3        2018         2018.3        2019  \
# 0  결혼해야 함 (%)  결혼할 필요 없음 (%)  결혼해야 함 (%)  결혼할 필요 없음 (%)  결혼해야 함 (%)
# 1        53.9            5.3        42.9            7.8        45.8
#
#           2019.3        2020         2020.3
# 0  결혼할 필요 없음 (%)  결혼해야 함 (%)  결혼할 필요 없음 (%)
# 1            6.2          42            6.2

# %%
#출산율 데이터 전처리
DIR_PATH='../Data2/'
FILE_NAME=DIR_PATH+'출산율.xlsx'
FILE_NAME
# Out:
# '../Data2/출산율.xlsx'

# %%
# df 형태 데이터로 로딩
birth=pd.read_excel(FILE_NAME, skiprows=2)

# %%
# birth 데이터프레임 정보 확인
birth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 52 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4 non-null      object
#  1   1970        4 non-null      object
#  2   1971        2 non-null      object
#  3   1972        2 non-null      float64
#  4   1973        2 non-null      float64
#  5   1974        2 non-null      float64
#  6   1975        2 non-null      float64
#  7   1976        2 non-null      float64
#  8   1977        2 non-null      float64
#  9   1978        2 non-null      float64
#  10  1979        2 non-null      float64
#  11  1980        2 non-null      float64
#  12  1981        2 non-null      float64
#  13  1982        2 non-null      float64
#  14  1983        2 non-null      float64
#  15  1984        2 non-null      float64
#  16  1985        2 non-null      float64
#  17  1986        2 non-null      float64
#  18  1987        2 non-null      float64
#  19  1988        2 non-null      float64
#  20  1989        2 non-null      float64
#  21  1990        2 non-null      float64
#  22  1991        2 non-null      float64
#  23  1992        2 non-null      float64
#  24  1993        2 non-null      float64
#  25  1994        2 non-null      float64
#  26  1995        2 non-null      float64
#  27  1996        2 non-null      float64
#  28  1997        2 non-null      float64
#  29  1998        2 non-null      float64
#  30  1999        2 non-null      float64
#  31  2000        2 non-null      float64
#  32  2001        2 non-null      float64
#  33  2002        2 non-null      float64
#  34  2003        2 non-null      float64
#  35  2004        2 non-null      float64
#  36  2005        2 non-null      float64
#  37  2006        2 non-null      float64
#  38  2007        2 non-null      float64
#  39  2008        2 non-null      float64
#  40  2009        2 non-null      float64
#  41  2010        2 non-null      float64
#  42  2011        2 non-null      float64
#  43  2012        2 non-null      float64
#  44  2013        2 non-null      float64
#  45  2014        2 non-null      float64
#  46  2015        2 non-null      float64
#  47  2016        2 non-null      float64
#  48  2017        2 non-null      float64
#  49  2018        2 non-null      float64
#  50  2019        2 non-null      float64
#  51  2020        2 non-null      float64
# dtypes: float64(49), object(3)
# memory usage: 1.8+ KB

# %%
# 2,3행 삭제
birth=birth.drop([2,3])
birth
# Out:
#   Unnamed: 0     1970     1971    1972    1973    1974    1975   1976    1977  \
# 0      출생아 수  1,007.0  1,025.0  953.00  966.00  923.00  874.00  796.0  825.00
# 1     합계 출산율    4.530    4.540    4.12    4.07    3.77    3.43    3.0    2.99
#
#      1978  ...     2011     2012     2013     2014     2015     2016     2017  \
# 0  751.00  ...  471.300  484.600  436.500  435.400  438.400  406.200  357.800
# 1    2.64  ...    1.244    1.297    1.187    1.205    1.239    1.172    1.052
#
#       2018     2019    2020
# 0  326.800  302.700  272.30
# 1    0.977    0.918    0.84
#
# [2 rows x 52 columns]

# %%
# 2011~2020 열 추출
birth=birth.iloc[:,-10:]

# %%
# 인덱스 라벨 바꾸기
birth=birth.rename(index={0:'출생아수', 1:'합계출산율'})
birth
# Out:
#           2011     2012     2013     2014     2015     2016     2017     2018  \
# 출생아수   471.300  484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계출산율    1.244    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#           2019    2020
# 출생아수   302.700  272.30
# 합계출산율    0.918    0.84

# %% [markdown]
# # 결혼율과 출산율의 상관계수

# %%
# 전국 결혼 건수만 추출
m=marriage.loc['전국']

#출생아수만 추출
b=birth.iloc[0]

# %%
# 타입 통일
b1=b.astype(int)
m1=m.astype(int)

# %%
# 시리즈 두 개 합치기
result1=pd.concat([b1,m1],axis=1)

# 컬럼명 바꾸기 
result1=result1.rename(columns={'전국':'결혼건수'})
result1
# Out:
#       출생아수   결혼건수
# 2011   471  27882
# 2012   484  26009
# 2013   436  26215
# 2014   435  24789
# 2015   438  26737
# 2016   406  24285
# 2017   357  22292
# 2018   326  20610
# 2019   302  17942
# 2020   272  18144

# %%
# 결혼건수와 출생아수의 상관계수
result1.corr()
# Out:
#           출생아수      결혼건수
# 출생아수  1.000000  0.964917
# 결혼건수  0.964917  1.000000

# %%
# 교육비 부담도
import pandas as pd
DIR_PATH='../Data2/'
FILE_NAME=DIR_PATH+'교육비 부담도.xls'
FILE_NAME
# Out:
# '../Data2/교육비 부담도.xls'

# %%
# DF 형태 데이터로 로딩
edu=pd.read_excel(FILE_NAME, skiprows=2)
edu.info()
edu
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      object
#  1   Unnamed: 1  9 non-null      object
#  2   2008        7 non-null      float64
#  3   2010        7 non-null      float64
#  4   2012        7 non-null      float64
#  5   2014        7 non-null      float64
#  6   2016        7 non-null      float64
#  7   2018        7 non-null      float64
#  8   2020        7 non-null      float64
# dtypes: float64(7), object(2)
# memory usage: 848.0+ bytes
#   Unnamed: 0                                         Unnamed: 1  2008  2010  \
# 0         전체                                                NaN  79.8  78.4
# 1         지역                                                 동부  80.5  78.7
# 2        NaN                                                읍면부  75.9  76.6
# 3     가구주 연령                                             30-39세  71.9  72.5
# 4        NaN                                             40-49세  82.7  79.8
# 5        NaN                                             50-59세  82.6  79.7
# 6        NaN                                             60세 이상  74.9  75.4
# 7        출처:                                         통계청, 「사회조사   NaN   NaN
# 8        주석:  1) 교육비부담도는 학생 자녀를 둔 가구주 중 소득에 비해 자녀 교육비가 가정 경제...   NaN   NaN
# 9        NaN                             2) 30세 이상 가구주를 대상으로 함.   NaN   NaN
#
#    2012  2014  2016  2018  2020
# 0  73.0  69.3  65.3  64.4  64.1
# 1  73.7  70.4  65.9  65.4  65.3
# 2  68.6  62.0  61.1  58.2  56.2
# 3  63.8  61.7  56.9  55.9  56.5
# 4  73.2  68.8  67.2  66.5  64.4
# 5  76.7  73.4  65.1  64.1  66.9
# 6  77.4  70.4  64.2  65.1  59.6
# 7   NaN   NaN   NaN   NaN   NaN
# 8   NaN   NaN   NaN   NaN   NaN
# 9   NaN   NaN   NaN   NaN   NaN

# %%
# 2008, 2010 열 삭제
edu=edu.drop(['2008', '2010'], axis=1)
edu
# Out:
#   Unnamed: 0                                         Unnamed: 1  2012  2014  \
# 0         전체                                                NaN  73.0  69.3
# 1         지역                                                 동부  73.7  70.4
# 2        NaN                                                읍면부  68.6  62.0
# 3     가구주 연령                                             30-39세  63.8  61.7
# 4        NaN                                             40-49세  73.2  68.8
# 5        NaN                                             50-59세  76.7  73.4
# 6        NaN                                             60세 이상  77.4  70.4
# 7        출처:                                         통계청, 「사회조사   NaN   NaN
# 8        주석:  1) 교육비부담도는 학생 자녀를 둔 가구주 중 소득에 비해 자녀 교육비가 가정 경제...   NaN   NaN
# 9        NaN                             2) 30세 이상 가구주를 대상으로 함.   NaN   NaN
#
#    2016  2018  2020
# 0  65.3  64.4  64.1
# 1  65.9  65.4  65.3
# 2  61.1  58.2  56.2
# 3  56.9  55.9  56.5
# 4  67.2  66.5  64.4
# 5  65.1  64.1  66.9
# 6  64.2  65.1  59.6
# 7   NaN   NaN   NaN
# 8   NaN   NaN   NaN
# 9   NaN   NaN   NaN

# %% [markdown]
# # 교육비 부담도-결혼율 상관계수

# %%
# 교육비 부담도 df에서 0번 행과 짝수년도만 추출
edu1=edu.loc[0, ['2012', '2014', '2016', '2018', '2020']]
edu1=edu1.astype(float)

# %%
# 결혼율 df에서 '전국'열과 짝수년도 열만 추출
m=marriage.loc['전국', ['2012', '2014', '2016', '2018', '2020']]
m=m.astype(float)

# %%
# 교육비 부담도와 결혼율에서 추출한 시리즈 합치기
result2=pd.concat([edu1,m],axis=1)

# 컬럼명 바꾸기
result2=result2.rename(columns={0:'교육비 부담도', '전국':'결혼건수'})

# %%
# 교육비 부담도와 결혼건수의 상관계수
result2.corr()
# Out:
#           교육비 부담도      결혼건수
# 교육비 부담도  1.000000  0.804733
# 결혼건수     0.804733  1.000000

# %% [markdown]
# # 교육비 부담도-출산율 상관계수

# %%
# 교육비 부담도 시리즈, 출산아수 시리즈 합치기
result3=pd.concat([edu1,b1],axis=1)

# 연도 통일
result3=result3.drop(['2011','2013', '2015', '2017', '2019'])

# 컬럼명 바꾸기
result3=result3.rename(columns={0:'교육비 부담도'})

result3
# Out:
#       교육비 부담도  출생아수
# 2012     73.0   484
# 2014     69.3   435
# 2016     65.3   406
# 2018     64.4   326
# 2020     64.1   272

# %%
# 결혼 건수, 출생아수 상관계수
result3.corr()
# Out:
#           교육비 부담도      출생아수
# 교육비 부담도  1.000000  0.882197
# 출생아수     0.882197  1.000000

# %% [markdown]
# # '결혼율 - 출산율' 그래프

# %%
import matplotlib.pyplot as plt

# %%
# matplotlib 한글 font 설정
from matplotlib import font_manager as fm, rc

# 한글폰트 설정
font_path='../font/malgun.ttf'
font_name=fm.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
result1
# Out:
#       출생아수   결혼건수
# 2011   471  27882
# 2012   484  26009
# 2013   436  26215
# 2014   435  24789
# 2015   438  26737
# 2016   406  24285
# 2017   357  22292
# 2018   326  20610
# 2019   302  17942
# 2020   272  18144

# %%
# x축, y축 지정
x=result1.index
y1=result1['출생아수'].to_list()
y2=result1['결혼건수'].to_list()

# 다중 플롯 지정
fig, ax1 = plt.subplots()
ax1.plot(x, y1, label='출산아수', color = 'red')
ax1.set_ylabel('출산아수', color = 'red')
ax1.legend()

# x축 공유
ax2 = ax1.twinx()
ax2.plot(x, y2, label='결혼건수 ',color = 'blue')
ax2.set_ylabel('결혼건수', color = 'blue')

ax2.legend(loc='upper left')

plt.title('결혼율-출산율')
ax1.set_xlabel('년도')
plt.show()

# %% [markdown]
# # '교육비 부담도 - 출산율' 그래프

# %%
result3
# Out:
#       교육비 부담도  출생아수
# 2012     73.0   484
# 2014     69.3   435
# 2016     65.3   406
# 2018     64.4   326
# 2020     64.1   272

# %%
x=result3.index
y1=result3['교육비 부담도'].to_list()
y2=result3['출생아수'].to_list()

# 다중 플롯을 지정
fig, ax1 = plt.subplots()
ax1.plot(x, y1, label='교육비 부담도', color = 'green')
ax1.set_ylabel('교육비 부담도', color = 'green')
ax1.legend()

# twinx로 x축을 공유
ax2 = ax1.twinx()
ax2.plot(x, y2, label='출생아수', color = 'orange')
ax2.set_ylabel('출생아수', color = 'orange')
ax2.legend(loc='upper left')

plt.title('교육비 부담도-출생아수')
ax1.set_xlabel('년도')
plt.show()

# %% [markdown]
# # 교육비 부담도 - 결혼율 그래프

# %%
result2
# Out:
#       교육비 부담도     결혼건수
# 2012     73.0  26009.0
# 2014     69.3  24789.0
# 2016     65.3  24285.0
# 2018     64.4  20610.0
# 2020     64.1  18144.0

# %%
x=result2.index
y1=result2['교육비 부담도'].to_list()
y2=result2['결혼건수'].to_list()

# ax1은 y1에 대한 그래프
fig, ax1 = plt.subplots()
ax1.plot(x, y1, label='교육비 부담도', color = 'black')
ax1.set_ylabel('교육비 부담도', color = 'black')
ax1.legend()

# twinx로 x축을 공유
ax2 = ax1.twinx()
ax2.plot(x, y2, label='결혼건수', color = 'purple')
ax2.set_ylabel('결혼건수', color = 'purple')
ax2.legend(loc='upper left')

plt.title('교육비 부담도-결혼율')
ax1.set_xlabel('년도')
plt.show()

# %%
# 가장먼저확대해야하는출산정책
DIR_PATH='../Data2/'
FILE_NAME=DIR_PATH+'가장먼저확대해야하는출산정책.xlsx'
FILE_NAME
# Out:
# '../Data2/가장먼저확대해야하는출산정책.xlsx'

# %%
system=pd.read_excel(FILE_NAME)

# %%
system.head()
# Out:
#    특성별(1)   특성별(2)              2021     2021.1                  2021.2  \
# 0  특성별(1)   특성별(2)  임신, 출산 의료비 지원 확대  출산 장려금 확대  출산 휴가 장려 및 출산 휴가 급여 보장
# 1      전체       소계              11.2        8.9                    10.3
# 2      성별       남자              12.7       11.5                     9.8
# 3     NaN       여자               9.5          6                    10.9
# 4     연령별  만18-24세              13.5        9.6                    10.9
#
#                    2021.3           2021.4                       2021.5  \
# 0  육아 휴직 장려 및 육아 휴직 급여 확대  임신, 출산기 근로시간 단축  육아, 돌봄기 근로시간 단축(자녀돌봄 휴가 확대)
# 1                    10.4              3.6                          6.5
# 2                     9.4              3.4                          6.5
# 3                    11.5              3.9                          6.5
# 4                    10.4              4.8                          5.7
#
#                                2021.6      2021.7            2021.8  \
# 0  배우자 육아 참여 확대(배우자 출산휴가, 육아휴직 사용 확산)  아동수당 지원 확대  국공립 어린이집, 유치원 확대
# 1                                 8.5         6.9               5.3
# 2                                 8.3         6.4               4.2
# 3                                 8.7         7.4               6.6
# 4                                 7.1         6.9                 4
#
#                   2021.9                     2021.10        2021.11 2021.12
# 0  가정 내 아이돌봄서비스 확대 및 내실화  온종일 돌봄체계의 안정적 정착(학교, 지역사회)  자녀의 교육비 부담 완화      기타
# 1                    5.1                         8.4           14.3     0.6
# 2                    4.9                         7.6           14.6     0.8
# 3                    5.4                         9.2           13.9     0.5
# 4                    4.5                         8.2           13.9     0.4

# %%
system=system.iloc[[0,1]]
system
# Out:
#    특성별(1)  특성별(2)              2021     2021.1                  2021.2  \
# 0  특성별(1)  특성별(2)  임신, 출산 의료비 지원 확대  출산 장려금 확대  출산 휴가 장려 및 출산 휴가 급여 보장
# 1      전체      소계              11.2        8.9                    10.3
#
#                    2021.3           2021.4                       2021.5  \
# 0  육아 휴직 장려 및 육아 휴직 급여 확대  임신, 출산기 근로시간 단축  육아, 돌봄기 근로시간 단축(자녀돌봄 휴가 확대)
# 1                    10.4              3.6                          6.5
#
#                                2021.6      2021.7            2021.8  \
# 0  배우자 육아 참여 확대(배우자 출산휴가, 육아휴직 사용 확산)  아동수당 지원 확대  국공립 어린이집, 유치원 확대
# 1                                 8.5         6.9               5.3
#
#                   2021.9                     2021.10        2021.11 2021.12
# 0  가정 내 아이돌봄서비스 확대 및 내실화  온종일 돌봄체계의 안정적 정착(학교, 지역사회)  자녀의 교육비 부담 완화      기타
# 1                    5.1                         8.4           14.3     0.6

# %%
system=system.drop(['특성별(1)', '특성별(2)'], axis=1)
system=system.T
system.columns=['장려책', '비율']
system
# Out:
#                                         장려책    비율
# 2021                       임신, 출산 의료비 지원 확대  11.2
# 2021.1                            출산 장려금 확대   8.9
# 2021.2               출산 휴가 장려 및 출산 휴가 급여 보장  10.3
# 2021.3               육아 휴직 장려 및 육아 휴직 급여 확대  10.4
# 2021.4                      임신, 출산기 근로시간 단축   3.6
# 2021.5          육아, 돌봄기 근로시간 단축(자녀돌봄 휴가 확대)   6.5
# 2021.6   배우자 육아 참여 확대(배우자 출산휴가, 육아휴직 사용 확산)   8.5
# 2021.7                           아동수당 지원 확대   6.9
# 2021.8                     국공립 어린이집, 유치원 확대   5.3
# 2021.9                가정 내 아이돌봄서비스 확대 및 내실화   5.1
# 2021.10          온종일 돌봄체계의 안정적 정착(학교, 지역사회)   8.4
# 2021.11                       자녀의 교육비 부담 완화  14.3
# 2021.12                                  기타   0.6

# %%
labels=[]
plt.pie(system['비율'])
# Out:
# ([<matplotlib.patches.Wedge at 0x23f40060790>,
#   <matplotlib.patches.Wedge at 0x23f40060af0>,
#   <matplotlib.patches.Wedge at 0x23f40060fd0>,
#   <matplotlib.patches.Wedge at 0x23f4007e4f0>,
#   <matplotlib.patches.Wedge at 0x23f4007e9d0>,
#   <matplotlib.patches.Wedge at 0x23f4007eeb0>,
#   <matplotlib.patches.Wedge at 0x23f4008a3d0>,
#   <matplotlib.patches.Wedge at 0x23f4008a8b0>,
#   <matplotlib.patches.Wedge at 0x23f4008ad90>,
#   <matplotlib.patches.Wedge at 0x23f400972b0>,
#   <matplotlib.patches.Wedge at 0x23f40060760>,
#   <matplotlib.patches.Wedge at 0x23f40097c40>,
#   <matplotlib.patches.Wedge at 0x23f400a4160>],
#  [Text(1.0326072570491793, 0.37910717836697616, ''),
#   Text(0.6096899308487441, 0.9155753318114538, ''),
#   Text(-0.017277852357453292, 1.0998642988195926, ''),
#   Text(-0.6796453651485793, 0.8649174397779562, ''),
#   Text(-0.9832254193023666, 0.49322183126630303, ''),
#   Text(-1.0880306418363663, 0.1618311540623278, ''),
#   Text(-1.0429122167233946, -0.34976293143941845, ''),
#   Text(-0.7605259652696064, -0.7947328206074878, ''),
#   Text(-0.40814847366169077, -1.0214767855647198, ''),
#   Text(-0.05872029900375305, -1.098431575695505, ''),
#   Text(0.3985024497097969, -1.0252784000335182, ''),
#   Text(0.9721419381626831, -0.5147232771745437, ''),
#   Text(1.0998045767871416, -0.02073385825301928, '')])
